# %%
import pandas as pd
# Load the penguins dataset
penguin = pd.read_csv("../ M1.01/penguins_classification.csv")

# %%
#How many features are numerical? How many features are categorical?
penguin.dtypes
# Out:
# Culmen Length (mm)    float64
# Culmen Depth (mm)     float64
# Species                object
# dtype: object

# %%
#What are the different penguins species available in the dataset and how many samples of each species are there?
penguin["Species"].value_counts()
# Out:
# Species
# Adelie       151
# Gentoo       123
# Chinstrap     68
# Name: count, dtype: int64

# %%
#Plot histograms for the numerical features
penguin.hist(figsize=(10, 5))
# Out:
# array([[<Axes: title={'center': 'Culmen Length (mm)'}>,
#         <Axes: title={'center': 'Culmen Depth (mm)'}>]], dtype=object)

# %%
#Show features distribution for each class
import seaborn as sn
sn.pairplot( penguin, hue="Species")
